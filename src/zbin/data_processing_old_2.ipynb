# %%
import pandas as pd

# %%
#loading the original dataset
df = pd.read_csv("../data/processed_data_test.csv")
display(df)
# Out:
#       index  DE_B01  DE_B09  DE_B10  DE_B11  DE_B12  DE_B15  DE_B16  DE_B18  \
# 0      7008   16888      88   21618    4624     140     384       0   21954
# 1      7009   16826      88   24620    4595      98     384       0   21356
# 2      7010   16854      88   25390    4567      95     385       0   20734
# 3      7011   16963      88   24538    4530     146     386       0   20330
# 4      7012   17167      88   15568    4560     156     388       0   20706
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1748   8756   18411      92   11779    4908     150     396       0   16757
# 1749   8757   18058      92   15420    4885      99     396       0   15590
# 1750   8758   17879      92   16490    4867     113     396       0   14325
# 1751   8759   17702      95   12912    4838     169     400       0   12742
# 1752   8760   13083      80    6152    3607     218     309       0    9500
#
# ...
